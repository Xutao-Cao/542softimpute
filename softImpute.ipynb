# %% [markdown]
# ### Imports

# %%
from fancyimpute import SoftImpute
import numpy as np
import pandas as pd
import random
from sklearn.metrics import mean_squared_error

# %% [markdown]
# ### Helper Functions

# %%
def load_dataset(file_path, name):
    if name == "ml-100k":
        col_names = ["user_id", "item_id", "rating", "timestamp"]
        df = pd.read_csv(file_path, sep="\t", header=None, names=col_names)
    else:
        col_names = ["user_id", "item_id", "rating", "timestamp"]
        df = pd.read_csv(file_path, sep="::", header=None, names=col_names, engine="python")
    return df

def create_matrix(df):
    num_users = df["user_id"].nunique()
    num_items = df["item_id"].nunique()
    matrix = np.zeros((num_users, num_items))
    matrix[:] = np.nan
    print(matrix.size)
    user_mapping = {user_id: idx for idx, user_id in enumerate(df["user_id"].unique())}
    item_mapping = {item_id: idx for idx, item_id in enumerate(df["item_id"].unique())}

    for row in df.itertuples():
        matrix[user_mapping[row[1]], item_mapping[row[2]]] = row[3]
    print(df.shape[0])
    return matrix

def remove_half_entries(matrix):
    non_nan_indices = np.nonzero(~np.isnan(matrix))
    non_nan_count = len(non_nan_indices[0])
    to_remove_count = non_nan_count // 2

    removal_indices = random.sample(range(non_nan_count), to_remove_count)
    removed_entries = []

    for idx in removal_indices:
        row = non_nan_indices[0][idx]
        col = non_nan_indices[1][idx]
        removed_entries.append((row, col, matrix[row, col]))
        matrix[row, col] = np.nan

    return matrix, removed_entries

def soft_impute(matrix, max_iters=100, convergence_threshold=0.001):
    imputer = SoftImpute(max_iters=max_iters, convergence_threshold=convergence_threshold)
    return imputer.fit_transform(matrix)

def load_matrix_from_csv(file_path):
    df = pd.read_csv(file_path, header=0, index_col=0)
    df = df.replace("NA", np.nan)
    return df

def save_matrix_to_csv(matrix, file_path):
    matrix.to_csv(file_path)

# %% [markdown]
# ### Main

# %%
CONFIG = {
    "max_iters": 1000,
    "seed": 123,
    "dataset": 'ml-100k' # "ml-100k" or "ml-1m"
}

# %%
if CONFIG["dataset"] == 'ml-100k':
    data_file = "./ml-100k/u.data"
else:
    data_file = "./ml-1m/ratings.dat"
df = load_dataset(data_file, CONFIG["dataset"])
random.seed(CONFIG["seed"])
user_item_matrix = create_matrix(df)
masked_matrix, removed_entries = remove_half_entries(user_item_matrix.copy())

completed_matrix = soft_impute(masked_matrix, CONFIG["max_iters"])

ground_truth = np.array([entry[2] for entry in removed_entries])
imputed_values = np.array([completed_matrix[entry[0], entry[1]] for entry in removed_entries])

mse = mean_squared_error(ground_truth, imputed_values)
print("MSE between imputed missing half and ground truth missing half:", mse)
# Out:
# 1586126
# 100000
# [SoftImpute] Max Singular Value of X_init = 322.519224
# [SoftImpute] Iter 1: observed MAE=0.575325 rank=647
# [SoftImpute] Iter 2: observed MAE=0.555040 rank=554
# [SoftImpute] Iter 3: observed MAE=0.538576 rank=496
# [SoftImpute] Iter 4: observed MAE=0.525129 rank=453
# [SoftImpute] Iter 5: observed MAE=0.513662 rank=419
# [SoftImpute] Iter 6: observed MAE=0.503861 rank=392
# [SoftImpute] Iter 7: observed MAE=0.495277 rank=369
# [SoftImpute] Iter 8: observed MAE=0.487728 rank=351
# [SoftImpute] Iter 9: observed MAE=0.480981 rank=333
# [SoftImpute] Iter 10: observed MAE=0.474841 rank=318
# [SoftImpute] Iter 11: observed MAE=0.469357 rank=305
# [SoftImpute] Iter 12: observed MAE=0.464522 rank=295
# [SoftImpute] Iter 13: observed MAE=0.460023 rank=284
# [SoftImpute] Iter 14: observed MAE=0.455803 rank=275
# [SoftImpute] Iter 15: observed MAE=0.451988 rank=266
# [SoftImpute] Iter 16: observed MAE=0.448577 rank=259
# [SoftImpute] Iter 17: observed MAE=0.445504 rank=252
# [SoftImpute] Iter 18: observed MAE=0.442685 rank=245
# [SoftImpute] Iter 19: observed MAE=0.439945 rank=239
# [SoftImpute] Iter 20: observed MAE=0.437294 rank=232
# [SoftImpute] Iter 21: observed MAE=0.434904 rank=226
# [SoftImpute] Iter 22: observed MAE=0.432743 rank=222
# [SoftImpute] Iter 23: observed MAE=0.430778 rank=217
# [SoftImpute] Iter 24: observed MAE=0.429020 rank=213
# [SoftImpute] Iter 25: observed MAE=0.427281 rank=208
# [SoftImpute] Iter 26: observed MAE=0.425619 rank=204
# [SoftImpute] Iter 27: observed MAE=0.424098 rank=200
# [SoftImpute] Iter 28: observed MAE=0.422580 rank=196
# [SoftImpute] Iter 29: observed MAE=0.421275 rank=194
# [SoftImpute] Iter 30: observed MAE=0.420073 rank=191
# [SoftImpute] Iter 31: observed MAE=0.418790 rank=185
# [SoftImpute] Iter 32: observed MAE=0.417525 rank=182
# [SoftImpute] Iter 33: observed MAE=0.416414 rank=180
# [SoftImpute] Iter 34: observed MAE=0.415475 rank=178
# [SoftImpute] Iter 35: observed MAE=0.414633 rank=176
# [SoftImpute] Iter 36: observed MAE=0.413799 rank=173
# [SoftImpute] Iter 37: observed MAE=0.412921 rank=171
# [SoftImpute] Iter 38: observed MAE=0.412218 rank=170
# [SoftImpute] Iter 39: observed MAE=0.411486 rank=167
# [SoftImpute] Iter 40: observed MAE=0.410791 rank=164
# [SoftImpute] Iter 41: observed MAE=0.410061 rank=162
# [SoftImpute] Iter 42: observed MAE=0.409348 rank=160
# [SoftImpute] Iter 43: observed MAE=0.408753 rank=158
# [SoftImpute] Iter 44: observed MAE=0.408138 rank=156
# [SoftImpute] Iter 45: observed MAE=0.407576 rank=154
# [SoftImpute] Iter 46: observed MAE=0.407041 rank=152
# [SoftImpute] Iter 47: observed MAE=0.406515 rank=151
# [SoftImpute] Iter 48: observed MAE=0.406014 rank=149
# [SoftImpute] Iter 49: observed MAE=0.405581 rank=148
# [SoftImpute] Iter 50: observed MAE=0.405213 rank=147
# [SoftImpute] Iter 51: observed MAE=0.404844 rank=145
# [SoftImpute] Iter 52: observed MAE=0.404431 rank=144
# [SoftImpute] Iter 53: observed MAE=0.404076 rank=143
# [SoftImpute] Iter 54: observed MAE=0.403725 rank=141
# [SoftImpute] Iter 55: observed MAE=0.403399 rank=141
# [SoftImpute] Iter 56: observed MAE=0.403112 rank=140
# [SoftImpute] Iter 57: observed MAE=0.402872 rank=139
# [SoftImpute] Iter 58: observed MAE=0.402591 rank=138
# [SoftImpute] Iter 59: observed MAE=0.402309 rank=137
# [SoftImpute] Iter 60: observed MAE=0.402059 rank=135
# [SoftImpute] Iter 61: observed MAE=0.401779 rank=134
# [SoftImpute] Iter 62: observed MAE=0.401514 rank=133
# [SoftImpute] Iter 63: observed MAE=0.401267 rank=133
# [SoftImpute] Iter 64: observed MAE=0.401061 rank=132
# [SoftImpute] Iter 65: observed MAE=0.400864 rank=132
# [SoftImpute] Iter 66: observed MAE=0.400670 rank=131
# [SoftImpute] Iter 67: observed MAE=0.400487 rank=130
# [SoftImpute] Iter 68: observed MAE=0.400299 rank=129
# [SoftImpute] Iter 69: observed MAE=0.400121 rank=129
# [SoftImpute] Iter 70: observed MAE=0.399937 rank=128
# [SoftImpute] Iter 71: observed MAE=0.399746 rank=127
# [SoftImpute] Iter 72: observed MAE=0.399576 rank=127
# [SoftImpute] Iter 73: observed MAE=0.399370 rank=125
# [SoftImpute] Iter 74: observed MAE=0.399190 rank=125
# [SoftImpute] Iter 75: observed MAE=0.399046 rank=125
# [SoftImpute] Iter 76: observed MAE=0.398910 rank=124
# [SoftImpute] Iter 77: observed MAE=0.398753 rank=122
# [SoftImpute] Iter 78: observed MAE=0.398592 rank=122
# [SoftImpute] Iter 79: observed MAE=0.398452 rank=121
# [SoftImpute] Iter 80: observed MAE=0.398321 rank=121
# [SoftImpute] Iter 81: observed MAE=0.398194 rank=120
# [SoftImpute] Iter 82: observed MAE=0.398070 rank=120
# [SoftImpute] Iter 83: observed MAE=0.397965 rank=120
# [SoftImpute] Iter 84: observed MAE=0.397871 rank=119
# [SoftImpute] Iter 85: observed MAE=0.397761 rank=119
# [SoftImpute] Iter 86: observed MAE=0.397668 rank=119
# [SoftImpute] Iter 87: observed MAE=0.397584 rank=119
# [SoftImpute] Iter 88: observed MAE=0.397506 rank=119
# [SoftImpute] Iter 89: observed MAE=0.397397 rank=117
# [SoftImpute] Iter 90: observed MAE=0.397292 rank=117
# [SoftImpute] Iter 91: observed MAE=0.397185 rank=116
# [SoftImpute] Iter 92: observed MAE=0.397089 rank=116
# [SoftImpute] Iter 93: observed MAE=0.397003 rank=115
# [SoftImpute] Iter 94: observed MAE=0.396901 rank=115
# [SoftImpute] Iter 95: observed MAE=0.396813 rank=115
# [SoftImpute] Iter 96: observed MAE=0.396729 rank=114
# [SoftImpute] Iter 97: observed MAE=0.396639 rank=114
# [SoftImpute] Iter 98: observed MAE=0.396561 rank=114
# [SoftImpute] Iter 99: observed MAE=0.396472 rank=113
# [SoftImpute] Iter 100: observed MAE=0.396390 rank=113
# [SoftImpute] Iter 101: observed MAE=0.396319 rank=113
# [SoftImpute] Iter 102: observed MAE=0.396249 rank=112
# [SoftImpute] Iter 103: observed MAE=0.396170 rank=112
# [SoftImpute] Iter 104: observed MAE=0.396089 rank=111
# [SoftImpute] Iter 105: observed MAE=0.396006 rank=111
# [SoftImpute] Iter 106: observed MAE=0.395936 rank=111
# [SoftImpute] Iter 107: observed MAE=0.395873 rank=111
# [SoftImpute] Iter 108: observed MAE=0.395812 rank=110
# [SoftImpute] Iter 109: observed MAE=0.395741 rank=110
# [SoftImpute] Iter 110: observed MAE=0.395680 rank=110
# [SoftImpute] Iter 111: observed MAE=0.395612 rank=109
# [SoftImpute] Iter 112: observed MAE=0.395549 rank=109
# [SoftImpute] Iter 113: observed MAE=0.395495 rank=109
# [SoftImpute] Iter 114: observed MAE=0.395445 rank=109
# [SoftImpute] Iter 115: observed MAE=0.395400 rank=109
# [SoftImpute] Iter 116: observed MAE=0.395355 rank=108
# [SoftImpute] Iter 117: observed MAE=0.395305 rank=108
# [SoftImpute] Iter 118: observed MAE=0.395262 rank=108
# [SoftImpute] Iter 119: observed MAE=0.395221 rank=108
# [SoftImpute] Iter 120: observed MAE=0.395183 rank=108
# [SoftImpute] Iter 121: observed MAE=0.395145 rank=108
# [SoftImpute] Iter 122: observed MAE=0.395108 rank=108
# [SoftImpute] Iter 123: observed MAE=0.395070 rank=108
# [SoftImpute] Iter 124: observed MAE=0.395022 rank=107
# [SoftImpute] Iter 125: observed MAE=0.394977 rank=107
# [SoftImpute] Iter 126: observed MAE=0.394937 rank=107
# [SoftImpute] Iter 127: observed MAE=0.394891 rank=106
# [SoftImpute] Iter 128: observed MAE=0.394847 rank=106
# [SoftImpute] Iter 129: observed MAE=0.394807 rank=106
# [SoftImpute] Iter 130: observed MAE=0.394769 rank=106
# [SoftImpute] Iter 131: observed MAE=0.394733 rank=106
# [SoftImpute] Iter 132: observed MAE=0.394698 rank=106
# [SoftImpute] Iter 133: observed MAE=0.394664 rank=106
# [SoftImpute] Iter 134: observed MAE=0.394631 rank=106
# [SoftImpute] Iter 135: observed MAE=0.394599 rank=106
# [SoftImpute] Iter 136: observed MAE=0.394568 rank=106
# [SoftImpute] Iter 137: observed MAE=0.394537 rank=106
# [SoftImpute] Iter 138: observed MAE=0.394502 rank=105
# [SoftImpute] Iter 139: observed MAE=0.394465 rank=105
# [SoftImpute] Iter 140: observed MAE=0.394431 rank=105
# [SoftImpute] Iter 141: observed MAE=0.394399 rank=105
# [SoftImpute] Iter 142: observed MAE=0.394368 rank=105
# [SoftImpute] Iter 143: observed MAE=0.394339 rank=105
# [SoftImpute] Iter 144: observed MAE=0.394311 rank=105
# [SoftImpute] Iter 145: observed MAE=0.394281 rank=104
# [SoftImpute] Iter 146: observed MAE=0.394247 rank=104
# [SoftImpute] Iter 147: observed MAE=0.394214 rank=104
# [SoftImpute] Iter 148: observed MAE=0.394184 rank=104
# [SoftImpute] Iter 149: observed MAE=0.394149 rank=103
# [SoftImpute] Iter 150: observed MAE=0.394117 rank=103
# [SoftImpute] Iter 151: observed MAE=0.394086 rank=103
# [SoftImpute] Iter 152: observed MAE=0.394058 rank=103
# [SoftImpute] Iter 153: observed MAE=0.394029 rank=103
# [SoftImpute] Iter 154: observed MAE=0.394002 rank=103
# [SoftImpute] Iter 155: observed MAE=0.393975 rank=103
# [SoftImpute] Iter 156: observed MAE=0.393949 rank=103
# [SoftImpute] Iter 157: observed MAE=0.393922 rank=103
# [SoftImpute] Iter 158: observed MAE=0.393895 rank=103
# [SoftImpute] Iter 159: observed MAE=0.393869 rank=103
# [SoftImpute] Iter 160: observed MAE=0.393844 rank=102
# [SoftImpute] Iter 161: observed MAE=0.393814 rank=102
# [SoftImpute] Iter 162: observed MAE=0.393786 rank=102
# [SoftImpute] Iter 163: observed MAE=0.393758 rank=102
# [SoftImpute] Iter 164: observed MAE=0.393729 rank=101
# [SoftImpute] Iter 165: observed MAE=0.393699 rank=101
# [SoftImpute] Iter 166: observed MAE=0.393671 rank=101
# [SoftImpute] Iter 167: observed MAE=0.393645 rank=101
# [SoftImpute] Iter 168: observed MAE=0.393619 rank=101
# [SoftImpute] Iter 169: observed MAE=0.393594 rank=101
# [SoftImpute] Iter 170: observed MAE=0.393568 rank=100
# [SoftImpute] Iter 171: observed MAE=0.393541 rank=100
# [SoftImpute] Iter 172: observed MAE=0.393516 rank=100
# [SoftImpute] Iter 173: observed MAE=0.393494 rank=100
# [SoftImpute] Iter 174: observed MAE=0.393472 rank=100
# [SoftImpute] Iter 175: observed MAE=0.393452 rank=100
# [SoftImpute] Iter 176: observed MAE=0.393433 rank=100
# [SoftImpute] Iter 177: observed MAE=0.393415 rank=100
# [SoftImpute] Iter 178: observed MAE=0.393398 rank=100
# [SoftImpute] Iter 179: observed MAE=0.393381 rank=100
# [SoftImpute] Iter 180: observed MAE=0.393361 rank=99
# [SoftImpute] Iter 181: observed MAE=0.393341 rank=99
# [SoftImpute] Iter 182: observed MAE=0.393323 rank=99
# [SoftImpute] Iter 183: observed MAE=0.393306 rank=99
# [SoftImpute] Iter 184: observed MAE=0.393289 rank=99
# [SoftImpute] Iter 185: observed MAE=0.393273 rank=99
# [SoftImpute] Iter 186: observed MAE=0.393257 rank=99
# [SoftImpute] Iter 187: observed MAE=0.393241 rank=99
# [SoftImpute] Iter 188: observed MAE=0.393226 rank=99
# [SoftImpute] Iter 189: observed MAE=0.393211 rank=99
# [SoftImpute] Iter 190: observed MAE=0.393197 rank=99
# [SoftImpute] Iter 191: observed MAE=0.393182 rank=99
# [SoftImpute] Iter 192: observed MAE=0.393168 rank=99
# [SoftImpute] Iter 193: observed MAE=0.393154 rank=99
# [SoftImpute] Iter 194: observed MAE=0.393140 rank=99
# [SoftImpute] Iter 195: observed MAE=0.393127 rank=99
# [SoftImpute] Iter 196: observed MAE=0.393113 rank=99
# [SoftImpute] Iter 197: observed MAE=0.393100 rank=99
# [SoftImpute] Iter 198: observed MAE=0.393087 rank=99
# [SoftImpute] Iter 199: observed MAE=0.393075 rank=99
# [SoftImpute] Iter 200: observed MAE=0.393062 rank=99
# [SoftImpute] Iter 201: observed MAE=0.393050 rank=99
# [SoftImpute] Iter 202: observed MAE=0.393037 rank=99
# [SoftImpute] Iter 203: observed MAE=0.393025 rank=99
# [SoftImpute] Iter 204: observed MAE=0.393013 rank=99
# [SoftImpute] Iter 205: observed MAE=0.392996 rank=98
# [SoftImpute] Iter 206: observed MAE=0.392981 rank=98
# [SoftImpute] Iter 207: observed MAE=0.392968 rank=98
# [SoftImpute] Iter 208: observed MAE=0.392955 rank=98
# [SoftImpute] Iter 209: observed MAE=0.392942 rank=98
# [SoftImpute] Iter 210: observed MAE=0.392930 rank=98
# [SoftImpute] Iter 211: observed MAE=0.392919 rank=98
# [SoftImpute] Iter 212: observed MAE=0.392907 rank=98
# [SoftImpute] Iter 213: observed MAE=0.392896 rank=98
# [SoftImpute] Iter 214: observed MAE=0.392885 rank=98
# [SoftImpute] Iter 215: observed MAE=0.392873 rank=98
# [SoftImpute] Iter 216: observed MAE=0.392862 rank=98
# [SoftImpute] Iter 217: observed MAE=0.392851 rank=98
# [SoftImpute] Iter 218: observed MAE=0.392840 rank=98
# [SoftImpute] Iter 219: observed MAE=0.392829 rank=98
# [SoftImpute] Iter 220: observed MAE=0.392818 rank=98
# [SoftImpute] Iter 221: observed MAE=0.392808 rank=98
# [SoftImpute] Iter 222: observed MAE=0.392798 rank=98
# [SoftImpute] Iter 223: observed MAE=0.392785 rank=97
# [SoftImpute] Iter 224: observed MAE=0.392773 rank=97
# [SoftImpute] Iter 225: observed MAE=0.392761 rank=97
# [SoftImpute] Iter 226: observed MAE=0.392750 rank=97
# [SoftImpute] Iter 227: observed MAE=0.392739 rank=97
# [SoftImpute] Iter 228: observed MAE=0.392729 rank=97
# [SoftImpute] Iter 229: observed MAE=0.392719 rank=97
# [SoftImpute] Iter 230: observed MAE=0.392709 rank=97
# [SoftImpute] Iter 231: observed MAE=0.392699 rank=97
# [SoftImpute] Iter 232: observed MAE=0.392689 rank=97
# [SoftImpute] Iter 233: observed MAE=0.392679 rank=97
# [SoftImpute] Iter 234: observed MAE=0.392669 rank=97
# [SoftImpute] Iter 235: observed MAE=0.392660 rank=97
# [SoftImpute] Iter 236: observed MAE=0.392651 rank=97
# [SoftImpute] Iter 237: observed MAE=0.392642 rank=97
# [SoftImpute] Iter 238: observed MAE=0.392633 rank=97
# [SoftImpute] Iter 239: observed MAE=0.392625 rank=97
# [SoftImpute] Iter 240: observed MAE=0.392616 rank=97
# [SoftImpute] Iter 241: observed MAE=0.392608 rank=97
# [SoftImpute] Iter 242: observed MAE=0.392599 rank=97
# [SoftImpute] Iter 243: observed MAE=0.392591 rank=97
# [SoftImpute] Iter 244: observed MAE=0.392582 rank=97
# [SoftImpute] Iter 245: observed MAE=0.392574 rank=97
# [SoftImpute] Iter 246: observed MAE=0.392565 rank=97
# [SoftImpute] Iter 247: observed MAE=0.392557 rank=97
# [SoftImpute] Iter 248: observed MAE=0.392549 rank=97
# [SoftImpute] Iter 249: observed MAE=0.392540 rank=97
# [SoftImpute] Iter 250: observed MAE=0.392532 rank=97
# [SoftImpute] Iter 251: observed MAE=0.392524 rank=97
# [SoftImpute] Iter 252: observed MAE=0.392516 rank=97
# [SoftImpute] Iter 253: observed MAE=0.392507 rank=97
# [SoftImpute] Iter 254: observed MAE=0.392499 rank=97
# [SoftImpute] Iter 255: observed MAE=0.392491 rank=97
# [SoftImpute] Iter 256: observed MAE=0.392483 rank=97
# [SoftImpute] Iter 257: observed MAE=0.392475 rank=97
# [SoftImpute] Iter 258: observed MAE=0.392467 rank=97
# [SoftImpute] Iter 259: observed MAE=0.392459 rank=97
# [SoftImpute] Iter 260: observed MAE=0.392451 rank=97
# [SoftImpute] Iter 261: observed MAE=0.392443 rank=97
# [SoftImpute] Iter 262: observed MAE=0.392435 rank=97
# [SoftImpute] Iter 263: observed MAE=0.392427 rank=97
# [SoftImpute] Iter 264: observed MAE=0.392420 rank=97
# [SoftImpute] Iter 265: observed MAE=0.392412 rank=97
# [SoftImpute] Iter 266: observed MAE=0.392405 rank=97
# [SoftImpute] Iter 267: observed MAE=0.392397 rank=97
# [SoftImpute] Iter 268: observed MAE=0.392390 rank=97
# [SoftImpute] Iter 269: observed MAE=0.392383 rank=97
# [SoftImpute] Iter 270: observed MAE=0.392375 rank=97
# [SoftImpute] Iter 271: observed MAE=0.392368 rank=97
# [SoftImpute] Iter 272: observed MAE=0.392361 rank=97
# [SoftImpute] Iter 273: observed MAE=0.392354 rank=97
# [SoftImpute] Iter 274: observed MAE=0.392346 rank=97
# [SoftImpute] Iter 275: observed MAE=0.392339 rank=97
# [SoftImpute] Iter 276: observed MAE=0.392332 rank=97
# [SoftImpute] Iter 277: observed MAE=0.392325 rank=97
# [SoftImpute] Iter 278: observed MAE=0.392318 rank=97
# [SoftImpute] Iter 279: observed MAE=0.392312 rank=97
# [SoftImpute] Iter 280: observed MAE=0.392305 rank=97
# [SoftImpute] Iter 281: observed MAE=0.392298 rank=97
# [SoftImpute] Iter 282: observed MAE=0.392292 rank=97
# [SoftImpute] Iter 283: observed MAE=0.392285 rank=97
# [SoftImpute] Iter 284: observed MAE=0.392279 rank=97
# [SoftImpute] Iter 285: observed MAE=0.392272 rank=97
# [SoftImpute] Iter 286: observed MAE=0.392265 rank=96
# [SoftImpute] Iter 287: observed MAE=0.392258 rank=96
# [SoftImpute] Iter 288: observed MAE=0.392250 rank=96
# [SoftImpute] Iter 289: observed MAE=0.392243 rank=96
# [SoftImpute] Iter 290: observed MAE=0.392237 rank=96
# [SoftImpute] Iter 291: observed MAE=0.392230 rank=96
# [SoftImpute] Iter 292: observed MAE=0.392223 rank=96
# [SoftImpute] Iter 293: observed MAE=0.392216 rank=96
# [SoftImpute] Iter 294: observed MAE=0.392209 rank=96
# [SoftImpute] Iter 295: observed MAE=0.392203 rank=96
# [SoftImpute] Iter 296: observed MAE=0.392196 rank=96
# [SoftImpute] Iter 297: observed MAE=0.392189 rank=96
# [SoftImpute] Iter 298: observed MAE=0.392183 rank=96
# [SoftImpute] Iter 299: observed MAE=0.392176 rank=96
# [SoftImpute] Iter 300: observed MAE=0.392170 rank=96
# [SoftImpute] Iter 301: observed MAE=0.392163 rank=96
# [SoftImpute] Iter 302: observed MAE=0.392156 rank=96
# [SoftImpute] Iter 303: observed MAE=0.392150 rank=96
# [SoftImpute] Iter 304: observed MAE=0.392143 rank=96
# [SoftImpute] Iter 305: observed MAE=0.392136 rank=96
# [SoftImpute] Iter 306: observed MAE=0.392129 rank=96
# [SoftImpute] Iter 307: observed MAE=0.392123 rank=96
# [SoftImpute] Iter 308: observed MAE=0.392116 rank=96
# [SoftImpute] Iter 309: observed MAE=0.392109 rank=96
# [SoftImpute] Iter 310: observed MAE=0.392102 rank=96
# [SoftImpute] Iter 311: observed MAE=0.392095 rank=96
# [SoftImpute] Iter 312: observed MAE=0.392088 rank=96
# [SoftImpute] Iter 313: observed MAE=0.392082 rank=96
# [SoftImpute] Iter 314: observed MAE=0.392075 rank=96
# [SoftImpute] Iter 315: observed MAE=0.392068 rank=96
# [SoftImpute] Iter 316: observed MAE=0.392062 rank=96
# [SoftImpute] Iter 317: observed MAE=0.392055 rank=96
# [SoftImpute] Iter 318: observed MAE=0.392048 rank=96
# [SoftImpute] Iter 319: observed MAE=0.392041 rank=96
# [SoftImpute] Iter 320: observed MAE=0.392035 rank=96
# [SoftImpute] Iter 321: observed MAE=0.392028 rank=96
# [SoftImpute] Iter 322: observed MAE=0.392021 rank=96
# [SoftImpute] Iter 323: observed MAE=0.392015 rank=96
# [SoftImpute] Iter 324: observed MAE=0.392008 rank=96
# [SoftImpute] Iter 325: observed MAE=0.392001 rank=96
# [SoftImpute] Iter 326: observed MAE=0.391995 rank=96
# [SoftImpute] Iter 327: observed MAE=0.391988 rank=96
# [SoftImpute] Iter 328: observed MAE=0.391982 rank=96
# [SoftImpute] Iter 329: observed MAE=0.391975 rank=96
# [SoftImpute] Iter 330: observed MAE=0.391969 rank=96
# [SoftImpute] Iter 331: observed MAE=0.391962 rank=95
# [SoftImpute] Iter 332: observed MAE=0.391955 rank=95
# [SoftImpute] Iter 333: observed MAE=0.391948 rank=95
# [SoftImpute] Iter 334: observed MAE=0.391941 rank=95
# [SoftImpute] Iter 335: observed MAE=0.391934 rank=95
# [SoftImpute] Iter 336: observed MAE=0.391928 rank=95
# [SoftImpute] Iter 337: observed MAE=0.391921 rank=95
# [SoftImpute] Iter 338: observed MAE=0.391915 rank=95
# [SoftImpute] Iter 339: observed MAE=0.391909 rank=95
# [SoftImpute] Iter 340: observed MAE=0.391902 rank=95
# [SoftImpute] Iter 341: observed MAE=0.391896 rank=95
# [SoftImpute] Iter 342: observed MAE=0.391889 rank=95
# [SoftImpute] Iter 343: observed MAE=0.391883 rank=95
# [SoftImpute] Iter 344: observed MAE=0.391876 rank=95
# [SoftImpute] Iter 345: observed MAE=0.391870 rank=95
# [SoftImpute] Iter 346: observed MAE=0.391864 rank=95
# [SoftImpute] Iter 347: observed MAE=0.391858 rank=95
# [SoftImpute] Iter 348: observed MAE=0.391851 rank=95
# [SoftImpute] Iter 349: observed MAE=0.391845 rank=95
# [SoftImpute] Iter 350: observed MAE=0.391839 rank=95
# [SoftImpute] Iter 351: observed MAE=0.391832 rank=95
# [SoftImpute] Iter 352: observed MAE=0.391826 rank=95
# [SoftImpute] Iter 353: observed MAE=0.391819 rank=95
# [SoftImpute] Iter 354: observed MAE=0.391813 rank=95
# [SoftImpute] Iter 355: observed MAE=0.391806 rank=95
# [SoftImpute] Iter 356: observed MAE=0.391799 rank=95
# [SoftImpute] Stopped after iteration 356 for lambda=6.450384
# MSE between imputed missing half and ground truth missing half: 1.178637146079569

# %% [markdown]
# ### Impute Feedback

# %%
matrix = load_matrix_from_csv('./Feedback.csv')
imputed_matrix = soft_impute(matrix)
imputed_matrix = np.round(imputed_matrix).astype(int)
completed_matrix =pd.DataFrame(imputed_matrix, index=matrix.index, columns=matrix.columns)
save_matrix_to_csv(completed_matrix, './imputedFeedback.csv')
# Out:
# [SoftImpute] Max Singular Value of X_init = 42.723211
# [SoftImpute] Iter 1: observed MAE=0.144944 rank=15
# [SoftImpute] Iter 2: observed MAE=0.144931 rank=15
# [SoftImpute] Iter 3: observed MAE=0.144926 rank=15
# [SoftImpute] Iter 4: observed MAE=0.144895 rank=15
# [SoftImpute] Iter 5: observed MAE=0.144873 rank=15
# [SoftImpute] Iter 6: observed MAE=0.144848 rank=15
# [SoftImpute] Iter 7: observed MAE=0.144845 rank=15
# [SoftImpute] Iter 8: observed MAE=0.144891 rank=15
# [SoftImpute] Iter 9: observed MAE=0.144927 rank=15
# [SoftImpute] Iter 10: observed MAE=0.144945 rank=15
# [SoftImpute] Iter 11: observed MAE=0.144272 rank=14
# [SoftImpute] Iter 12: observed MAE=0.143061 rank=14
# [SoftImpute] Iter 13: observed MAE=0.142581 rank=14
# [SoftImpute] Iter 14: observed MAE=0.142406 rank=14
# [SoftImpute] Iter 15: observed MAE=0.142348 rank=14
# [SoftImpute] Iter 16: observed MAE=0.142289 rank=14
# [SoftImpute] Iter 17: observed MAE=0.142208 rank=14
# [SoftImpute] Iter 18: observed MAE=0.142156 rank=14
# [SoftImpute] Iter 19: observed MAE=0.142147 rank=14
# [SoftImpute] Iter 20: observed MAE=0.142103 rank=14
# [SoftImpute] Iter 21: observed MAE=0.142039 rank=14
# [SoftImpute] Iter 22: observed MAE=0.141963 rank=14
# [SoftImpute] Iter 23: observed MAE=0.141884 rank=14
# [SoftImpute] Iter 24: observed MAE=0.141814 rank=14
# [SoftImpute] Iter 25: observed MAE=0.141722 rank=14
# [SoftImpute] Iter 26: observed MAE=0.141674 rank=14
# [SoftImpute] Iter 27: observed MAE=0.141678 rank=14
# [SoftImpute] Iter 28: observed MAE=0.141685 rank=14
# [SoftImpute] Iter 29: observed MAE=0.141662 rank=14
# [SoftImpute] Iter 30: observed MAE=0.140983 rank=13
# [SoftImpute] Iter 31: observed MAE=0.140560 rank=13
# [SoftImpute] Iter 32: observed MAE=0.140318 rank=13
# [SoftImpute] Iter 33: observed MAE=0.140169 rank=13
# [SoftImpute] Iter 34: observed MAE=0.140053 rank=12
# [SoftImpute] Iter 35: observed MAE=0.139633 rank=12
# [SoftImpute] Iter 36: observed MAE=0.139317 rank=12
# [SoftImpute] Iter 37: observed MAE=0.139044 rank=12
# [SoftImpute] Iter 38: observed MAE=0.138797 rank=12
# [SoftImpute] Iter 39: observed MAE=0.138577 rank=12
# [SoftImpute] Iter 40: observed MAE=0.138391 rank=12
# [SoftImpute] Iter 41: observed MAE=0.138255 rank=12
# [SoftImpute] Iter 42: observed MAE=0.138122 rank=12
# [SoftImpute] Iter 43: observed MAE=0.138049 rank=12
# [SoftImpute] Iter 44: observed MAE=0.137961 rank=12
# [SoftImpute] Iter 45: observed MAE=0.137858 rank=12
# [SoftImpute] Iter 46: observed MAE=0.137752 rank=12
# [SoftImpute] Iter 47: observed MAE=0.137683 rank=12
# [SoftImpute] Iter 48: observed MAE=0.137617 rank=12
# [SoftImpute] Iter 49: observed MAE=0.137551 rank=12
# [SoftImpute] Iter 50: observed MAE=0.137477 rank=12
# [SoftImpute] Iter 51: observed MAE=0.137408 rank=12
# [SoftImpute] Iter 52: observed MAE=0.137327 rank=12
# [SoftImpute] Iter 53: observed MAE=0.137226 rank=12
# [SoftImpute] Iter 54: observed MAE=0.137133 rank=12
# [SoftImpute] Iter 55: observed MAE=0.137077 rank=12
# [SoftImpute] Iter 56: observed MAE=0.137084 rank=12
# [SoftImpute] Iter 57: observed MAE=0.137104 rank=12
# [SoftImpute] Iter 58: observed MAE=0.137131 rank=12
# [SoftImpute] Iter 59: observed MAE=0.137168 rank=12
# [SoftImpute] Iter 60: observed MAE=0.137205 rank=12
# [SoftImpute] Iter 61: observed MAE=0.137255 rank=12
# [SoftImpute] Iter 62: observed MAE=0.137319 rank=12
# [SoftImpute] Iter 63: observed MAE=0.137380 rank=11
# [SoftImpute] Iter 64: observed MAE=0.137207 rank=11
# [SoftImpute] Iter 65: observed MAE=0.137115 rank=11
# [SoftImpute] Iter 66: observed MAE=0.137053 rank=11
# [SoftImpute] Iter 67: observed MAE=0.137006 rank=11
# [SoftImpute] Iter 68: observed MAE=0.136971 rank=11
# [SoftImpute] Iter 69: observed MAE=0.136948 rank=11
# [SoftImpute] Iter 70: observed MAE=0.136930 rank=11
# [SoftImpute] Iter 71: observed MAE=0.136916 rank=11
# [SoftImpute] Iter 72: observed MAE=0.136913 rank=11
# [SoftImpute] Iter 73: observed MAE=0.136910 rank=11
# [SoftImpute] Iter 74: observed MAE=0.136917 rank=11
# [SoftImpute] Iter 75: observed MAE=0.136926 rank=11
# [SoftImpute] Iter 76: observed MAE=0.136934 rank=11
# [SoftImpute] Iter 77: observed MAE=0.136947 rank=11
# [SoftImpute] Iter 78: observed MAE=0.136962 rank=11
# [SoftImpute] Iter 79: observed MAE=0.136977 rank=11
# [SoftImpute] Iter 80: observed MAE=0.136992 rank=11
# [SoftImpute] Iter 81: observed MAE=0.137007 rank=11
# [SoftImpute] Iter 82: observed MAE=0.137020 rank=11
# [SoftImpute] Iter 83: observed MAE=0.137033 rank=11
# [SoftImpute] Iter 84: observed MAE=0.137049 rank=11
# [SoftImpute] Iter 85: observed MAE=0.137065 rank=11
# [SoftImpute] Iter 86: observed MAE=0.137080 rank=11
# [SoftImpute] Iter 87: observed MAE=0.137095 rank=11
# [SoftImpute] Iter 88: observed MAE=0.137107 rank=11
# [SoftImpute] Iter 89: observed MAE=0.137119 rank=11
# [SoftImpute] Iter 90: observed MAE=0.137130 rank=11
# [SoftImpute] Iter 91: observed MAE=0.137142 rank=11
# [SoftImpute] Iter 92: observed MAE=0.137157 rank=11
# [SoftImpute] Iter 93: observed MAE=0.137173 rank=11
# [SoftImpute] Iter 94: observed MAE=0.137190 rank=11
# [SoftImpute] Iter 95: observed MAE=0.137205 rank=11
# [SoftImpute] Iter 96: observed MAE=0.137220 rank=11
# [SoftImpute] Iter 97: observed MAE=0.137234 rank=11
# [SoftImpute] Iter 98: observed MAE=0.137247 rank=11
# [SoftImpute] Iter 99: observed MAE=0.137259 rank=11
# [SoftImpute] Iter 100: observed MAE=0.137271 rank=11
# [SoftImpute] Stopped after iteration 100 for lambda=0.854464
